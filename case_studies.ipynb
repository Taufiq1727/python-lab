# %% [markdown]
# #### A college wants to process student mae=rks and identify toppers,failed students,and class average using functional programming

# %%
from functools import reduce

marks = [78, 45, 90, 32, 45, 67, 89]

passed = list(filter(lambda x: x >= 40, marks))

grace_marks = list(map(lambda x: x + 5, marks))

total = reduce(lambda x, y: x + y, marks)
average = total / len(marks)

print(passed)
print(grace_marks)
print(total)
print(average)
# Out:
# [78, 45, 90, 45, 67, 89]
# [83, 50, 95, 37, 50, 72, 94]
# 446
# 63.714285714285715

# %% [markdown]
# #### Employee Management system

# %%
# A company wants to:
# •	Increase salary by 10% 
# •	Find employees earning above ₹50,000 
# •	Calculate total salary expenditure 
# Program
from functools import reduce
salaries = [25000, 55000, 48000, 72000, 35000]
# Salary increment
updated_salary = list(map(lambda x: x * 1.10, salaries))
# High salary employees
high_salary = list(filter(lambda x: x > 50000, updated_salary))
# Total expenditure
total = reduce(lambda x, y: x + y, updated_salary)
print("Updated Salaries:", updated_salary)
print("High Salary Employees:", high_salary)
print("Total Salary:", total)
# Out:
# Updated Salaries: [27500.000000000004, 60500.00000000001, 52800.00000000001, 79200.0, 38500.0]
# High Salary Employees: [60500.00000000001, 52800.00000000001, 79200.0]
# Total Salary: 258500.00000000003
